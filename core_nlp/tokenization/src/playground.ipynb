# %%
DUMMY_TEXT = "Bu gün hava çok güzel"

vocab = {idx: bytes([idx]) for idx in range(256)}
for (p0, p1), idx in DUMMY_TEXT.items():
    vocab[idx] = vocab[0] + vocab[p1]
# Out:
# Running cells with '.venv (Python 3.13.3)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/Users/zephyrus/Projects/1337-NLP/.venv/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
# !pip3 install ipykernel
# Out:
# Running cells with '.venv (Python 3.13.3)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/Users/zephyrus/Projects/1337-NLP/.venv/bin/python -m pip install ipykernel -U --force-reinstall'
